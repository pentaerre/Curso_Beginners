# %% [markdown]
# <a href="https://colab.research.google.com/github/pentaerre/Curso_Beginners/blob/main/plotly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # REPRESENTACIÓN INTERACTIVA CON PLOTLY
#
#
# En el mercado hay soluciones ya integradas que permiten realizar gráficos interactivos. No siempre vamos a poder acceder a ellos o pagar esas licencias así que conocer cómo hacer este tipo de representaciones. Además, da mucho valor añadido a ciertas tareas y reporting.
# ¿Qué es plotly? Es una librería que permite hacer representación gráfica (como matplotlib o seaborn) pero además permite interactuar con los gráficos. Esto es muy potente porque permite hacer presentaciones y responder pregunta al momento sobre ciertos puntos. Vamos a explicar solo plotlib express que es un módulo que para hacer gráficos rápidos y fácilmente.
# La idea no es explicar el data analyitics que hay detrás de los gráficos más bien explicar que existen y que se pueden hacer. Así pues cojamos uno de los datasets más famosos para data analyticis, el iris dataset (https://es.wikipedia.org/wiki/Conjunto_de_datos_flor_iris).
#
#
#
# 1. Importamos la librería
# 2. Importamos el dataset (viene como ejemplo dentro de plotly, pero podríais añadir cualquier dataset de pandas)
# 3. Utilizamos el modulo scather en el que se configuran las siguientes opciones:
#
#     a. df: son los datos
#
#     b. x: es el nombre de la columna de df
#
#     c. y: es el nombre de la columna de df
#
#     d. color: es el color que van a tener los puntos de acuerdo a la columna de especie de iris como hay tres especies pues tendremos tres colores
#
#     e. marginal_y: el tipo de subgráfico que vamos a poner en el eje Y que va a ser de tipo violin
#
#     f. marginal_x: el tipo de subgráfico que vamos a poner en el eje X que va a ser de tipo violin
#
#     g. trendline: es el tipo de recta de regresión que vamos a introducir a los puntos de cada color
#
#     h. template: es el tipo de plantilla standard para la disposición del grafico

# %%
import plotly.express as px
df = px.data.iris()
fig = px.scatter(df, x="sepal_width", y="sepal_length", color="species", marginal_y="violin",
           marginal_x="box", trendline="ols", template="simple_white")
fig.show()

# Ejercicio intenta jugar con distintas opciones.
#    1. Que sucede si quitas template="simple_white"?. Busca y prueba más templates
#    2. Utiliza otras variables para representar del dataset.
#    3. ¿Como editarias los colores?
#    4. Utiliza otro tipo de recta de regresión
# Out:
# /usr/local/lib/python3.7/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning:
#
# pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b2c7155f-33d1-42d2-aedb-b441eb828a64" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
# ...

# %% [markdown]
# Vamos a utilizar otro tipo de grafico llamado categorías paralelas. Hay muchos tipos de representaciones y entenderlos todos y saber cuándo usarlos es trabajo de data analyitics, como ya se ha dicho aquí solo se va a mostrar tipos de representaciones de la forma más sencilla posible para abrir vuestra mente y dar visibilidad.
# Este ejemplo es sobre un dataset tambien incluido en plotly sobre propinas que da la gente. Cada columna es una de las variables y este tipo de grafico permite hacer una relación visual de las variables y el número de ocurrencias

# %%
import plotly.express as px
df = px.data.tips()
fig = px.parallel_categories(df, color="size", color_continuous_scale=px.colors.sequential.Jet)
fig.show()

#Ejercicio: Hay demasiadas variables de decisión, elimina "day"
#Ejercicio: utiliza este tipo de grafico con el iris dataset
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="a96f5703-68c2-4733-bb5d-9a2c5adba5d6" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("a96f5703-68c2-4733-bb5d-9a2c5adba5d6")) {
#                     Plotly.newPlot(
#                         'a96f5703-68c2-4733-bb5d-9a2c5adba5d6',
# ...
